# %%
from utilities import css_styles
css_styles()
# Out:
#         <style>
#         .info {
#             background-color: #fcf8e3; border-color: #faebcc; border-left: 5px solid #8a6d3b; padding: 0.5em; color: #8a6d3b;
#         }
#         .success {
#             background-color: #d9edf7; border-color: #bce8f1; border-left: 5px solid #31708f; padding: 0.5em; color: #31708f;
#         }
#         .error {
#             background-color: #f2dede; border-color: #ebccd1; border-left: 5px solid #a94442; padding: 0.5em; color: #a94442;
#         }
#         .warning {
#             background-color: #fcf8e3; border-color: #faebcc; border-left: 5px solid #8a6d3b; padding: 0.5em; color: #8a6d3b;
#         }
#         </style>

# %% [markdown]
# # IOOS System Test - Theme 1 - Scenario B - [Description](https://github.com/ioos/system-test/wiki/Development-of-Test-Themes#theme-1-baseline-assessment)
#
# ## Core Variable Strings
#
# This notebook looks at the IOOS core variables and uses the Marine Metadata Interoperability SPARQL endpoint to convert them to CF Standard names.  Each IOOS CSW server is then queryied for CF standard name that is associated with an IOOS Core Variable.
#
# ## Questions
# 1. Using a list of Core IOOS Variables and the MMI SPARQL service, can we search and quantify records from CSW endpoints that relate to core variables?

# %% [markdown]
# #### Get a list of the IOOS Core Variables from MMI

# %%
# Using RDF
from rdflib import Graph, Literal, BNode, Namespace, RDF, URIRef
g = Graph()
g.load("http://mmisw.org/ont/ioos/core_variable")
core_var_uri      = URIRef('http://mmisw.org/ont/ioos/core_variable/Core_Variable')
core_var_name_uri = URIRef('http://mmisw.org/ont/ioos/core_variable/name')
core_var_def_uri  = URIRef('http://mmisw.org/ont/ioos/core_variable/definition')

core_variables = []
for cv in g.subjects(predicate=RDF.type, object=core_var_uri):
    name = g.value(subject=cv, predicate=core_var_name_uri).value
    definition = g.value(subject=cv, predicate=core_var_def_uri).value
    core_variables.append((name, definition))

# %%
import pandas as pd
core_variables_names = [x for x,y in core_variables]
pd.DataFrame.from_records(core_variables, columns=("Name", "Definition",))
# Out:
#                       Name                          Definition
# 0    phytoplankton_species               Phytoplankton species
# 1         ice_distribution                    Ice distribution
# 2              ocean_color                         Ocean color
# 3         surface_currents                    Surface currents
# 4       optical_properties                  Optical properties
# 5            surface_waves                       Surface waves
# 6                 salinity                            Salinity
# 7              temperature                         Temperature
# 8         bottom_character                    Bottom character
# 9             fish_species                        Fish species
# 10  total_suspended_matter              Total suspended matter
# 11               heat_flux                           Heat flux
# 12                 acidity                             Acidity
# 13          fish_abundance                      Fish abundance
# 14     zooplankton_species                 Zooplankton species
# 15            contaminants                        Contaminants
# 16   zooplankton_abundance               Zooplankton abundance
# 17               sea_level                           Sea level
# 18                    wind            Wind Speed and Direction
# 19             stream_flow                         Stream flow
# 20               pathogens                           Pathogens
# 21     dissolved_nutrients                 Dissolved Nutrients
# 22        dissolved_oxygen                    Dissolved oxygen
# 23                    pco2  Partial pressure of carbon dioxide
# 24                    cdom      Color dissolved organic matter
# 25              bathymetry                          Bathymetry
#
# [26 rows x 2 columns]

# %% [markdown]
# <div class="error"><strong>Programmatic access to Core Variables</strong> - This isn't straight forward and should be abstracted into a library. See: https://github.com/ioos/system-test/issues/128</div>

# %% [markdown]
# #### Query MMI for CF standard names related to the IOOS Core Variables

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
sparql = SPARQLWrapper("http://mmisw.org/sparql")

query = """
PREFIX ioos: <http://mmisw.org/ont/ioos/parameter/>
SELECT DISTINCT ?cat ?parameter ?property ?value 
WHERE {?parameter a ioos:Parameter .
       # ?parameter ?property ?value .
       # ?cat skos:narrowMatch ?parameter .
       FILTER  (regex(str(?property), "Match", "i") && regex(str(?value), "cf", "i") )
      } 
ORDER BY ?cat ?parameter
"""
    
sparql.setQuery(query)
sparql.setReturnFormat(JSON)
j = sparql.query().convert()

cf_standard_uris  = list(set([ x["value"]["value"] for x in j.get("results").get("bindings") ]))
cf_standard_names = map(lambda x: x.split("/")[-1], cf_standard_uris)
pd.DataFrame.from_records(zip(cf_standard_names, cf_standard_uris), columns=("CF Name", "CF URI",))
# Out:
#                                               CF Name  \
# 0   sea_surface_height_correction_due_to_air_press...
# 1                 lagrangian_tendency_of_air_pressure
# 2                                radiation_wavelength
# 3        mole_concentration_of_phosphate_in_sea_water
# 4                                     platform_course
# 5   sea_surface_swell_wave_mean_period_from_varian...
# 6                                   wind_to_direction
# 7               air_pressure_at_convective_cloud_base
# 8   surface_partial_pressure_of_carbon_dioxide_in_...
# 9                            tendency_of_air_pressure
# 10          sea_surface_swell_wave_significant_height
# 11        moles_of_nitrate_per_unit_mass_in_sea_water
# 12  sea_surface_height_correction_due_to_air_press...
# 13     sea_surface_height_amplitude_due_to_earth_tide
# 14  mole_concentration_of_dissolved_organic_carbon...
# 15                        eastward_sea_water_velocity
# 16         water_surface_height_above_reference_datum
# 17                     sound_intensity_level_in_water
# 18  sea_surface_wave_mean_period_from_variance_spe...
# 19  sea_surface_wave_mean_period_from_variance_spe...
# 20         mole_concentration_of_nitrate_in_sea_water
# 21                                     northward_wind
# 22                            freezing_level_altitude
# 23       mass_concentration_of_phosphate_in_sea_water
# 24                             height_above_sea_floor
# 25                                      eastward_wind
# 26                       sound_intensity_level_in_air
# 27                                    air_temperature
# 28                                  depth_below_geoid
# 29                                           altitude
# 30  sea_surface_wind_wave_mean_period_from_varianc...
# 31  product_of_eastward_sea_water_velocity_and_sal...
# 32  surface_geostrophic_northward_sea_water_veloci...
# 33                                height_at_cloud_top
# 34         sea_surface_wave_variance_spectral_density
# 35           sea_surface_wind_wave_significant_height
# 36                    sea_floor_depth_below_sea_level
# 37  sea_surface_wind_wave_mean_period_from_varianc...
# 38                       northward_sea_water_velocity
# 39  sea_water_alkalinity_expressed_as_mole_equivalent
# 40                                              depth
# 41                    sea_surface_subskin_temperature
# 42                                   surface_altitude
# 43               air_pressure_at_convective_cloud_top
# 44               sea_water_ph_reported_on_total_scale
# 45                    sea_surface_wave_from_direction
# 46                  surface_downward_northward_stress
# 47                 sea_surface_wind_wave_to_direction
# 48  sea_surface_wind_wave_mean_period_from_varianc...
# 49                          air_pressure_at_sea_level
# 50                                         wind_speed
# 51                               platform_pitch_angle
# 52     radial_sea_water_velocity_away_from_instrument
# 53                                 cloud_top_altitude
# 54                    sea_water_pressure_at_sea_floor
# 55  moles_of_nitrate_and_nitrite_per_unit_mass_in_...
# 56  volume_absorption_coefficient_of_radiative_flu...
# 57    direction_of_radial_vector_away_from_instrument
# 58  sea_surface_wave_period_at_variance_spectral_d...
# 59                                cloud_base_altitude
#                                                   ...
#
#                                                CF URI
# 0   http://mmisw.org/ont/cf/parameter/sea_surface_...
# 1   http://mmisw.org/ont/cf/parameter/lagrangian_t...
# 2   http://mmisw.org/ont/cf/parameter/radiation_wa...
# 3   http://mmisw.org/ont/cf/parameter/mole_concent...
# 4   http://mmisw.org/ont/cf/parameter/platform_course
# 5   http://mmisw.org/ont/cf/parameter/sea_surface_...
# 6   http://mmisw.org/ont/cf/parameter/wind_to_dire...
# 7   http://mmisw.org/ont/cf/parameter/air_pressure...
# 8   http://mmisw.org/ont/cf/parameter/surface_part...
# 9   http://mmisw.org/ont/cf/parameter/tendency_of_...
# 10  http://mmisw.org/ont/cf/parameter/sea_surface_...
# 11  http://mmisw.org/ont/cf/parameter/moles_of_nit...
# 12  http://mmisw.org/ont/cf/parameter/sea_surface_...
# 13  http://mmisw.org/ont/cf/parameter/sea_surface_...
# 14  http://mmisw.org/ont/cf/parameter/mole_concent...
# 15  http://mmisw.org/ont/cf/parameter/eastward_sea...
# 16  http://mmisw.org/ont/cf/parameter/water_surfac...
# 17  http://mmisw.org/ont/cf/parameter/sound_intens...
# 18  http://mmisw.org/ont/cf/parameter/sea_surface_...
# 19  http://mmisw.org/ont/cf/parameter/sea_surface_...
# 20  http://mmisw.org/ont/cf/parameter/mole_concent...
# 21   http://mmisw.org/ont/cf/parameter/northward_wind
# 22  http://mmisw.org/ont/cf/parameter/freezing_lev...
# 23  http://mmisw.org/ont/cf/parameter/mass_concent...
# 24  http://mmisw.org/ont/cf/parameter/height_above...
# 25    http://mmisw.org/ont/cf/parameter/eastward_wind
# 26  http://mmisw.org/ont/cf/parameter/sound_intens...
# 27  http://mmisw.org/ont/cf/parameter/air_temperature
# 28  http://mmisw.org/ont/cf/parameter/depth_below_...
# 29         http://mmisw.org/ont/cf/parameter/altitude
# 30  http://mmisw.org/ont/cf/parameter/sea_surface_...
# 31  http://mmisw.org/ont/cf/parameter/product_of_e...
# 32  http://mmisw.org/ont/cf/parameter/surface_geos...
# 33  http://mmisw.org/ont/cf/parameter/height_at_cl...
# 34  http://mmisw.org/ont/cf/parameter/sea_surface_...
# 35  http://mmisw.org/ont/cf/parameter/sea_surface_...
# 36  http://mmisw.org/ont/cf/parameter/sea_floor_de...
# 37  http://mmisw.org/ont/cf/parameter/sea_surface_...
# 38  http://mmisw.org/ont/cf/parameter/northward_se...
# 39  http://mmisw.org/ont/cf/parameter/sea_water_al...
# 40            http://mmisw.org/ont/cf/parameter/depth
# 41  http://mmisw.org/ont/cf/parameter/sea_surface_...
# 42  http://mmisw.org/ont/cf/parameter/surface_alti...
# 43  http://mmisw.org/ont/cf/parameter/air_pressure...
# 44  http://mmisw.org/ont/cf/parameter/sea_water_ph...
# 45  http://mmisw.org/ont/cf/parameter/sea_surface_...
# 46  http://mmisw.org/ont/cf/parameter/surface_down...
# 47  http://mmisw.org/ont/cf/parameter/sea_surface_...
# 48  http://mmisw.org/ont/cf/parameter/sea_surface_...
# 49  http://mmisw.org/ont/cf/parameter/air_pressure...
# 50       http://mmisw.org/ont/cf/parameter/wind_speed
# 51  http://mmisw.org/ont/cf/parameter/platform_pit...
# 52  http://mmisw.org/ont/cf/parameter/radial_sea_w...
# 53  http://mmisw.org/ont/cf/parameter/cloud_top_al...
# 54  http://mmisw.org/ont/cf/parameter/sea_water_pr...
# 55  http://mmisw.org/ont/cf/parameter/moles_of_nit...
# 56  http://mmisw.org/ont/cf/parameter/volume_absor...
# 57  http://mmisw.org/ont/cf/parameter/direction_of...
# 58  http://mmisw.org/ont/cf/parameter/sea_surface_...
# 59  http://mmisw.org/ont/cf/parameter/cloud_base_a...
#                                                   ...
#
# [160 rows x 2 columns]

# %% [markdown]
# ### Searching CSW servers on variable names

# %%
# https://github.com/ioos/system-test/wiki/Service-Registries-and-Data-Catalogs
known_csw_servers = ['http://data.nodc.noaa.gov/geoportal/csw',
                     'http://www.nodc.noaa.gov/geoportal/csw',
                     'http://www.ngdc.noaa.gov/geoportal/csw',
                     'http://cwic.csiss.gmu.edu/cwicv1/discovery',
                     'http://geoport.whoi.edu/geoportal/csw',
                     'https://edg.epa.gov/metadata/csw',
                     'http://cmgds.marine.usgs.gov/geonetwork/srv/en/csw',
                     'http://cida.usgs.gov/gdp/geonetwork/srv/en/csw',
                     'http://geodiscover.cgdi.ca/wes/serviceManagerCSW/csw',
                     'http://geoport.whoi.edu/gi-cat/services/cswiso',
                     #https://data.noaa.gov/csw',
                     ]

# %% [markdown]
# <div class="error"><strong>CSW Server Broken</strong> - 'https://data.noaa.gov/csw' has been omitted because it is not working.  See: https://github.com/ioos/system-test/issues/130</div>

# %% [markdown]
# #### Subset which variables we should query by

# %%
# Query on Waves
variables_to_query = [ x for x in cf_standard_names if "sea_surface_height" in x ]
custom_variables   = [u"sea_surface_height", u"sea_surface_elevation"]

variables_to_query += custom_variables
variables_to_query
# Out:
# [u'sea_surface_height_correction_due_to_air_pressure_at_low_frequency',
#  u'sea_surface_height_correction_due_to_air_pressure_and_wind_at_high_frequency',
#  u'sea_surface_height_amplitude_due_to_earth_tide',
#  u'sea_surface_height_amplitude_due_to_equilibrium_ocean_tide',
#  u'sea_surface_height_above_sea_level',
#  u'sea_surface_height_above_reference_ellipsoid',
#  u'sea_surface_height_bias_due_to_sea_surface_roughness',
#  u'sea_surface_height_amplitude_due_to_pole_tide',
#  u'sea_surface_height_above_geoid',
#  u'sea_surface_height_amplitude_due_to_geocentric_ocean_tide',
#  u'sea_surface_height_amplitude_due_to_non_equilibrium_ocean_tide',
#  u'sea_surface_height',
#  u'sea_surface_elevation']

# %% [markdown]
# <div class="error"><strong>Missing CF Standard Names</strong> - "sea_surface_height" and "sea_surface_elevation" are valid CF Aliases but are not returned by MMI when running the SPARQL query.  We added them here manually. See: https://github.com/ioos/system-test/issues/129</div>

# %% [markdown]
# #### Construct CSW Filters

# %%
from owslib import fes

cf_name_filters = []
for cf_name in variables_to_query:
    text_filter   = fes.PropertyIsLike(propertyname='AnyText', literal="*%s*" % cf_name, wildCard='*')
    cf_name_filters.append(text_filter)

# %% [markdown]
# #### Query each CSW catalog for the cf_name_filters constructed above

# %%
#This cell searches the endpoints using the revised list of variable strings from the previous cell and returns basic information on the number of records and the titles of data sets available via each endpoint

from owslib.csw import CatalogueServiceWeb
from utilities import normalize_service_urn

var_results = []

for x in range(len(cf_name_filters)):
    var_name          = variables_to_query[x]
    single_var_filter = cf_name_filters[x]
    for url in known_csw_servers:
        try:
            csw = CatalogueServiceWeb(url, timeout=20)
            csw.getrecords2(constraints=[single_var_filter], maxrecords=1000, esn='full')
            for record, item in csw.records.items():
                for d in item.references:
                    result = dict(variable=var_name,
                                  scheme=normalize_service_urn(d['scheme']),
                                  url=d['url'],
                                  server=url,
                                  title=record.title())
                    var_results.append(result)
        except BaseException as e:
            print "- FAILED: %s - %s" % (url, e.msg)
# Out:
# - FAILED: http://cwic.csiss.gmu.edu/cwicv1/discovery - REQUEST_LIMITATION: TOO_MANY_RECORDS - The request asked for more records than can be handled. The maximum number designated in GetRecords request should be less than 200, please decrease the returned recorder number in request.
# - FAILED: http://cwic.csiss.gmu.edu/cwicv1/discovery - REQUEST_LIMITATION: TOO_MANY_RECORDS - The request asked for more records than can be handled. The maximum number designated in GetRecords request should be less than 200, please decrease the returned recorder number in request.
# - FAILED: http://cwic.csiss.gmu.edu/cwicv1/discovery - REQUEST_LIMITATION: TOO_MANY_RECORDS - The request asked for more records than can be handled. The maximum number designated in GetRecords request should be less than 200, please decrease the returned recorder number in request.
# - FAILED: http://cwic.csiss.gmu.edu/cwicv1/discovery - REQUEST_LIMITATION: TOO_MANY_RECORDS - The request asked for more records than can be handled. The maximum number designated in GetRecords request should be less than 200, please decrease the returned recorder number in request.
# - FAILED: http://cwic.csiss.gmu.edu/cwicv1/discovery - REQUEST_LIMITATION: TOO_MANY_RECORDS - The request asked for more records than can be handled. The maximum number designated in GetRecords request should be less than 200, please decrease the returned recorder number in request.
# - FAILED: http://cwic.csiss.gmu.edu/cwicv1/discovery - REQUEST_LIMITATION: TOO_MANY_RECORDS - The request asked for more records than can be handled. The maximum number designated in GetRecords request should be less than 200, please decrease the returned recorder number in request.
# - FAILED: http://cwic.csiss.gmu.edu/cwicv1/discovery - REQUEST_LIMITATION: TOO_MANY_RECORDS - The request asked for more records than can be handled. The maximum number designated in GetRecords request should be less than 200, please decrease the returned recorder number in request.
# - FAILED: http://cwic.csiss.gmu.edu/cwicv1/discovery - REQUEST_LIMITATION: TOO_MANY_RECORDS - The request asked for more records than can be handled. The maximum number designated in GetRecords request should be less than 200, please decrease the returned recorder number in request.
# - FAILED: http://cwic.csiss.gmu.edu/cwicv1/discovery - REQUEST_LIMITATION: TOO_MANY_RECORDS - The request asked for more records than can be handled. The maximum number designated in GetRecords request should be less than 200, please decrease the returned recorder number in request.
# - FAILED: http://cwic.csiss.gmu.edu/cwicv1/discovery - REQUEST_LIMITATION: TOO_MANY_RECORDS - The request asked for more records than can be handled. The maximum number designated in GetRecords request should be less than 200, please decrease the returned recorder number in request.
# - FAILED: http://cwic.csiss.gmu.edu/cwicv1/discovery - REQUEST_LIMITATION: TOO_MANY_RECORDS - The request asked for more records than can be handled. The maximum number designated in GetRecords request should be less than 200, please decrease the returned recorder number in request.
# - FAILED: http://cwic.csiss.gmu.edu/cwicv1/discovery - REQUEST_LIMITATION: TOO_MANY_RECORDS - The request asked for more records than can be handled. The maximum number designated in GetRecords request should be less than 200, please decrease the returned recorder number in request.
# - FAILED: http://cwic.csiss.gmu.edu/cwicv1/discovery - REQUEST_LIMITATION: TOO_MANY_RECORDS - The request asked for more records than can be handled. The maximum number designated in GetRecords request should be less than 200, please decrease the returned recorder number in request.

# %% [markdown]
# <div class="error"><strong>Paginating CSW Records</strong> - Some servers have a maximum amount of records you can retrieve at once. See: https://github.com/ioos/system-test/issues/126</div>

# %% [markdown]
# #### Load results into a Pandas DataFrame

# %%
# %matplotlib inline
import pandas as pd
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 500)

from IPython.display import HTML

df = pd.DataFrame(var_results)
df = df.drop_duplicates()

# %% [markdown]
# #### Results by variable

# %%
by_variable = pd.DataFrame(df.groupby("variable").size(), columns=("Number of services",))
by_variable.sort('Number of services', ascending=False).plot(kind="barh", figsize=(10,6,))

# %% [markdown]
# #### The number of service types for each model type

# %%
import math

var_service_summary = pd.DataFrame(df.groupby(["variable", "scheme"], sort=True).size(), columns=("Number of services",))
#HTML(model_service_summary.to_html())
var_service_plotter = var_service_summary.unstack("variable")
var_service_plot = var_service_plotter.plot(kind='barh', subplots=True, figsize=(12,34,), sharey=True)

# %% [markdown]
# #### Services per CSW server

# %%
services_per_csw = pd.DataFrame(df.groupby(["variable", "server"]).size(), columns=("Number of services",))
#HTML(records_per_csw.to_html())
var_csw_plotter = services_per_csw.unstack("variable")
var_csw_plot = var_csw_plotter.plot(kind='barh', subplots=True, figsize=(12,30,), sharey=True)
